# %%
import pandas as pd

# %% [markdown]
# ## Create sample scenario

# %%
df = pd.read_csv('eval_scenarios/eval_goal_gen_GT_scenarios.csv')

sampled_df = df.groupby('Goal Type', group_keys=False).apply(lambda x: x.sample(frac=35/len(df)))
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_6516\2062844013.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_df = df.groupby('Goal Type', group_keys=False).apply(lambda x: x.sample(frac=35/len(df)))

# %%
sampled_df.columns
# Out:
# Index(['Unnamed: 0', 'Goal Type', 'Num', 'Goal', 'SayCan Instruction',
#        'GT subgoals'],
#       dtype='object')

# %%
sampled_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
sampled_df.reset_index(drop=True, inplace=True)

# %%
sampled_df.to_csv('eval_scenarios/eval_goal_gen_GT_scenarios_sample.csv')

# %% [markdown]
# ## Evaluate scenario

# %%
df = pd.read_csv('outputs/eval_goal_gen20240920-160735.csv')

# %%
import pandas as pd
dd = pd.read_csv('eval_scenarios/eval_agent_adapt_GT_scenarios.csv')

# %%
dd.shape
# Out:
# (112, 28)

# %%
dd
# Out:
#      Unnamed: 0 Agent Condition Type  Num  \
# 0             1   1 - Robot negative  1.1
# 1             2                  NaN  NaN
# 2             3                  NaN  NaN
# 3             4                  NaN  NaN
# 4             5                  NaN  1.2
# ..          ...                  ...  ...
# 107         108                  NaN  NaN
# 108         109                  NaN  4.7
# 109         110                  NaN  NaN
# 110         111                  NaN  NaN
# 111         112                  NaN  NaN
#
#                                 Condition  Scenario  \
# 0    The robot can't pick pointy objects.         1
# 1    The robot can't pick pointy objects.         2
# 2    The robot can't pick pointy objects.         3
# 3    The robot can't pick pointy objects.         4
# 4                The robot can't get wet.         1
# ..                                    ...       ...
# 107              The human likes to cook.         4
# ...

# %%
dd.dropna(subset=['GT subgoals to favour'])
# Out:
#    Unnamed: 0 Agent Condition Type  Num                             Condition  \
# 0           1   1 - Robot negative  1.1  The robot can't pick pointy objects.
#
#    Scenario                                               Goal  \
# 0         1  I spilled my coke on the floor. I want to thro...
#
#                                             Subgoals GT subgoals to disfavour  \
# 0  coke, placed, trash can\nmop, used to clean, f...                     none
#
#   GT subgoals to favour  Unnamed: 9  ...  Unnamed: 18  Unnamed: 19  \
# 0                  none         NaN  ...          NaN          NaN
#
#    Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 0          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 25  Unnamed: 26  Unnamed: 27
# 0          NaN          NaN          NaN
#
# [1 rows x 28 columns]

# %% [markdown]
# ## Results data

# %%
import pandas as pd

# %%
df = pd.read_csv('results/complete_eval_agent_adapt.csv', encoding='ISO-8859-1')

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df[df['OUTPUT - LLM subgoals to favour']!='[]']
# Out:
#      Test number  Condition number                        INPUT - Condition  \
# 8            9.0               1.3             The robot can't handle food.
# 28          29.0               2.1  The robot is good at cleaning surfaces.
# 29          30.0               NaN  The robot is good at cleaning surfaces.
# 30          31.0               NaN  The robot is good at cleaning surfaces.
# 31          32.0               NaN  The robot is good at cleaning surfaces.
# ..           ...               ...                                      ...
# 156          NaN               NaN                                      NaN
# 157          NaN               NaN                                      NaN
# 158          NaN               NaN                                      NaN
# 159          NaN               NaN                                      NaN
# 160          NaN               NaN                                      NaN
#
# ...
